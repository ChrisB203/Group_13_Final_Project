# %% [markdown]
# # Team GitHub Sucks Final Project
#
# ## Best Neighborhood by various emergency call statistics (Fire, Firearm Seizure, Crime):

# %% [markdown]
# ## Introduction
#
# **Before moving to a new area, its good to know how safe that place is before settling down. But safety is a concern about many different categories, so its important that we took information from different aspects to help give a well rounded estimate as to where the safest neighborhood is. For our project, we went ahead and looked at 3 different safety metrics to determine which neighborhood in Pittsburgh to determine which is the safest. So, lets find out, who has the safest neighborhood!**

# %% [markdown]
# **As said, we decided to look at 3 different safety metrics**
#
# * **Fires https://data.wprdc.org/dataset/fire-incidents-in-city-of-pittsburgh**
#
#     **If you were going to move, you most likely wouldn't want to be going somewhere where fires break out constantly. We have gathered information on how many fires break out in each neighborhood.**
#
# * **Weapon Seizure https://data.wprdc.org/dataset/pbp-fire-arm-seizures/resource/e967381d-d7e9-48e3-a2a2-39262f7fa5c4?view_id=4c4fa4d5-71cd-4aa7-92e8-18206b9140a0**
#
#     **Moving into an area where there are constant records of illegal firearms being seized isn't the best for your safety. We compiled and ranked each neighborhood's recorded firearm seizure rate.**
#
# * **Crime Rate https://data.wprdc.org/dataset/a-community-profile-of-pittsburgh-neighborhoods-1974/resource/8ce92a4b-fa62-45c3-8cee-cc58fefede75**
#
#     **Just like the other two, something that you want to avoid. By using each neighborhood's population and how many crimes occur, we figured out each neighborhood's crime rate and ranked them.**

# %% [markdown]
# ## Part 1: Fires in the City
#
# By Leon Pavolotsky

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("fire_incident_data.csv")
df.head(10)
# Out:
#       call_no  incident_type                     type_description  \
# 0  F160029985          111.0                        Building fire
# 1  F180022058          111.0                        Building fire
# 2  F180022102          131.0               Passenger vehicle fire
# 3  F170043431          131.0               Passenger vehicle fire
# 4  F180021111          111.0                        Building fire
# 5  F180021782          150.0          Outside rubbish fire, Other
# 6  F180022495          113.0  Cooking fire, confined to container
# 7  F180022546          111.0                        Building fire
# 8  F180022773          111.0                        Building fire
# 9  F170044316          131.0               Passenger vehicle fire
#
#                                           address           alarm_time  \
# 0       800 BLOCK CENTER ST, WILKINSBURG PA 15221  2016-04-21T05:01:04
# 1        1100 BLOCK JANE ST, WILKINSBURG PA 15221  2018-03-13T08:34:43
# ...

# %%
df['neighborhood'].value_counts()
# Out:
# Carrick                      280
# Central Business District    255
# South Side Flats             250
# Squirrel Hill South          247
# Hazelwood                    238
#                             ...
# St. Clair                     11
# East Carnegie                 11
# Mt. Oliver                    11
# Regent Square                  9
# Mount Oliver Borough           6
# Name: neighborhood, Length: 91, dtype: int64

# %%
df['alarms'].value_counts()
# Out:
# 1     4685
# 0     4128
# 2      188
# 3       98
# 4       29
# 5       10
# 6        1
# 7        1
# 19       1
# Name: alarms, dtype: int64

# %%
alarm_mask = df['alarms'] < 6
norm_alarms = df[alarm_mask]
norm_alarms.head(10)
# Out:
#       call_no  incident_type                     type_description  \
# 0  F160029985          111.0                        Building fire
# 1  F180022058          111.0                        Building fire
# 2  F180022102          131.0               Passenger vehicle fire
# 3  F170043431          131.0               Passenger vehicle fire
# 4  F180021111          111.0                        Building fire
# 5  F180021782          150.0          Outside rubbish fire, Other
# 6  F180022495          113.0  Cooking fire, confined to container
# 7  F180022546          111.0                        Building fire
# 8  F180022773          111.0                        Building fire
# 9  F170044316          131.0               Passenger vehicle fire
#
#                                           address           alarm_time  \
# 0       800 BLOCK CENTER ST, WILKINSBURG PA 15221  2016-04-21T05:01:04
# 1        1100 BLOCK JANE ST, WILKINSBURG PA 15221  2018-03-13T08:34:43
# ...

# %%
norm_alarms['alarms'].value_counts()
# Out:
# 1    4685
# 0    4128
# 2     188
# 3      98
# 4      29
# 5      10
# Name: alarms, dtype: int64

# %%
df_grouped = norm_alarms.groupby(by = 'neighborhood')['alarms'].sum()
df_lowest_sorted = df_grouped.sort_values(ascending = True)
df_lowest_sorted.head(10)
# Out:
# neighborhood
# Ridgemont               1
# Mount Oliver Borough    2
# New Homestead           2
# St. Clair               4
# Regent Square           4
# Hays                    5
# Bon Air                 5
# Chartiers City          6
# South Shore             6
# Mt. Oliver              6
# Name: alarms, dtype: int64

# %%
df_lowest_sorted.iloc[:20].plot(kind = "bar")

# %%
df_highest_sorted = df_grouped.sort_values(ascending = False)
df_highest_sorted.iloc[:20].plot(kind = "bar")

# %%
df_ranked = df_lowest_sorted.rank()
print(df_ranked)
# Out:
# neighborhood
# Ridgemont                     1.0
# Mount Oliver Borough          2.5
# New Homestead                 2.5
# St. Clair                     4.5
# Regent Square                 4.5
#                              ...
# Shadyside                    87.0
# Squirrel Hill South          88.0
# South Side Flats             89.0
# Central Business District    90.0
# Carrick                      91.0
# Name: alarms, Length: 91, dtype: float64

# %% [markdown]
# ## Part 2: Firearm Seizures
#
# By Chris Berarducci

# %%
info = pd.read_csv('Seizure.csv')
info.head(10)
# Out:
#                                            address  total_count  other_count  \
# 0    1700 BLOCK ARLINGTON AVE PITTSBURGH, PA 15210            2            0
# 1      BREVET WAY & MINTON ST PITTSBURGH, PA 15204            1            0
# 2   TERRACE ST & WHITRIDGE ST PITTSBURGH, PA 15213            1            0
# 3       3500 BLOCK GERBER AVE PITTSBURGH, PA 15212            1            0
# 4         7500 BLOCK KELLY ST PITTSBURGH, PA 15208            1            0
# 5          1900 BLOCK 5TH AVE PITTSBURGH, PA 15219            1            0
# 6      400 BLOCK S NEGLEY AVE PITTSBURGH, PA 15232            1            0
# 7      5200 BLOCK DRESDEN WAY PITTSBURGH, PA 15201            2            0
# 8        1100 BLOCK GRAND AVE PITTSBURGH, PA 15212            1            0
# 9  1600 BLOCK FALLOWFIELD AVE PITTSBURGH, PA 15216            1            0
#
#    pistol_count  revolver_count  rifle_count  shotgun_count  year  month  dow  \
# ...

# %%
collect = info['year'] > 2020
clear = info[collect]
clear.head(10)
# Out:
#                                             address  total_count  other_count  \
# 3391      2200 BLOCK WILNER DR PITTSBURGH, PA 15221            1            0
# 3392  BENNETT ST & STERRETT ST PITTSBURGH, PA 15208            1            0
# 3393  2800 BLOCK SHADELAND AVE PITTSBURGH, PA 15212            1            0
# 3394     1000 BLOCK BENTON AVE PITTSBURGH, PA 15212            1            0
# 3395  WOODLAND AVE & PLOUGH ST PITTSBURGH, PA 15212            1            0
# 3396       3100 BLOCK EWART DR PITTSBURGH, PA 15219            1            0
# 3397     7700 BLOCK BENNETT ST PITTSBURGH, PA 15221            1            0
# 3398    1600 BLOCK CRUCIBLE ST PITTSBURGH, PA 15205            1            0
# 3399     DAVIS AVE & CAMPUS ST PITTSBURGH, PA 15212            2            0
# 3400  400 BLOCK FORT PITT BLVD PITTSBURGH, PA 15219            1            0
#
#       pistol_count  revolver_count  rifle_count  shotgun_count  year  month  \
# ...

# %%
graphq = clear.value_counts('neighborhood')
graphq.iloc[0:15].plot(kind = "bar")

# %%
check = graphq > 3
final = graphq[check]
final_ranked = final.rank(ascending = False)
print(final_ranked)
# Out:
# neighborhood
# Homewood South          1.0
# South Side Flats        2.0
# East Hills              3.0
# Homewood North          4.0
# Marshall-Shadeland      5.5
#                        ...
# Central Oakland        59.0
# Chateau                59.0
# South Shore            59.0
# Lower Lawrenceville    59.0
# Point Breeze North     59.0
# Length: 62, dtype: float64

# %% [markdown]
# ## Part 3: Crime Rate
# By Danny Cohen

# %% [markdown]
# Let's first take a look at the raw data

# %%
arrests = pd.read_csv("all_arrests.csv")
arrests.head(10)
# Out:
#         neighborhood  population  overall_crime_rate  number_arrests_murder  \
# 0          31st Ward        7594                2.03                      0
# 1   Allegheny Center         588               52.04                      0
# 2     Allegheny West        1159               14.33                      1
# 3          Allentown        5042                3.13                      0
# 4          Arlington        4758                2.50                      0
# 5  Arlington Heights        1989                6.19                      0
# 6         Banksville        6235                1.94                      0
# 7  Bedford Dwellings        3635                2.64                      1
# 8          Beechview       12965                1.98                      1
# 9        Beltzhoover        5980                6.37                      1
#
#    crime_rate_murder  number_arrests_rape  crime_rate_rape  \
# 0               0.00                    1             0.01
# ...

# %% [markdown]
# Before we analyze the data, it is important to get an actual understanding of the data itself. Measures such as the **mean** and **median**, and creating a **histogram** of the population will give us a good idea of the population distribution throughout the neighborhoods.

# %%
#Data frame of only population to make mean/median functions easier
population_df = arrests['population']
#Helps determine a population filter
print("Mean:", round(population_df.mean()), "Median:", round(population_df.median()))

population_df.hist()
# Out:
# Mean: 7077 Median: 6127

# %%
population_df.plot(kind = "box")

# %% [markdown]
# It is also important to see if there's a strong relationship between population and crime rate in order to decide if a population threshold is necessary. A **scatterplot** is a very good representation of the relationship between the two variables

# %%
arrests[['population', 'overall_crime_rate']].sort_values(by=['overall_crime_rate'])
arrests.plot.scatter(x="population", y="overall_crime_rate")

# %% [markdown]
# Here, we see that aside from a few outliers, there is a very weak correlation between population and crime rate; as a result, a population threshold will not be used.

# %% [markdown]
# Now that we understand what our data will look like, we need to get rid of unnecessary columns. For the sake of this project, all major crimes will be weighed the same, so we only care about the overall crime rate, not the specific crime.

# %%
#Get rid of unnecessary columns and sorts by overall crime rate
filtered_df = arrests[['neighborhood', 'overall_crime_rate']]
filtered_df.sort_values(by=['overall_crime_rate'])
# Out:
#                             neighborhood  overall_crime_rate
# 27                        Harpen Hilltop                0.99
# 17  Crafton Heights - Westwood - Oakwood                1.41
# 41                           Morningside                1.61
# 12                      Brighton Heights                1.64
# 22                                Elliot                1.70
# ..                                   ...                 ...
# 69                       West End Valley               13.73
# 2                         Allegheny West               14.33
# 20                          East Liberty               16.63
# 62                             The Strip               33.56
# 1                       Allegheny Center               52.04
#
# [70 rows x 2 columns]

# %% [markdown]
# Now that our dataset is sorted by overall crime rate, we will assign a numerical value to each neighborhood. Rather than using a neighborhood's crime rate as a value, we will rank the neighborhoods 1 to 70 based on their respective crime rates. This way, we will have a controlled value to compare the metrics across all three datasets.

# %%
#Add column that ranks the neighborhoods from lowest crime rate to highest; stores a value 1 to 70
filtered_df['crimes_rank'] = filtered_df['overall_crime_rate'].rank(ascending = True)

#Creates new data frame that sorts values by rank
ranked_df = filtered_df[['neighborhood', 'crimes_rank']]
final_df = ranked_df.sort_values(by=['crimes_rank'])
# Out:
# <ipython-input-22-064f185debf9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['crimes_rank'] = filtered_df['overall_crime_rate'].rank(ascending = True)

# %% [markdown]
# Let's take a look at the 10 safest neighborhoods in terms of overall crime rate

# %%
final_df.head(10)
# Out:
#                             neighborhood  crimes_rank
# 27                        Harpen Hilltop          1.0
# 17  Crafton Heights - Westwood - Oakwood          2.0
# 41                           Morningside          3.0
# 12                      Brighton Heights          4.0
# 22                                Elliot          5.0
# 63                        Swisshelm Park          6.0
# 66                             Troy Hill          7.0
# 51                 Shadeland Halls Grove          8.0
# 68                   Upper Lawrenceville          9.0
# 56                      Southside Slopes         10.5

# %% [markdown]
# Now let's check out the bottom 10

# %%
final_df.tail(10)
# Out:
#           neighborhood  crimes_rank
# 40         Middle Hill         61.0
# 39          Manchester         62.0
# 16  Central North Side         63.0
# 65           The Bluff         64.0
# 38       Lower Oakland         65.0
# 69     West End Valley         66.0
# 2       Allegheny West         67.0
# 20        East Liberty         68.0
# 62           The Strip         69.0
# 1     Allegheny Center         70.0

# %% [markdown]
# ## Part 4: Putting it all Together

# %%
df_first_merged = pd.merge(df_ranked, final_df, how = 'left', on = 'neighborhood')

# %%
df_first_merged.head(10)
# Out:
#            neighborhood  alarms  crimes_rank
# 0             Ridgemont     1.0          NaN
# 1  Mount Oliver Borough     2.5          NaN
# 2         New Homestead     2.5          NaN
# 3             St. Clair     4.5         52.0
# 4         Regent Square     4.5         43.0
# 5                  Hays     6.5          NaN
# 6               Bon Air     6.5         24.0
# 7        Chartiers City     9.0          NaN
# 8           South Shore     9.0          NaN
# 9            Mt. Oliver     9.0          NaN

# %%
df_second_merged = df_first_merged.merge(final_ranked.to_frame(), how = 'left', on ='neighborhood')

# %%
df_second_merged.head(10)
# Out:
#            neighborhood  alarms  crimes_rank     0
# 0             Ridgemont     1.0          NaN   NaN
# 1  Mount Oliver Borough     2.5          NaN   NaN
# 2         New Homestead     2.5          NaN   NaN
# 3             St. Clair     4.5         52.0   NaN
# 4         Regent Square     4.5         43.0   NaN
# 5                  Hays     6.5          NaN   NaN
# 6               Bon Air     6.5         24.0   NaN
# 7        Chartiers City     9.0          NaN   NaN
# 8           South Shore     9.0          NaN  59.0
# 9            Mt. Oliver     9.0          NaN   NaN

# %%
df_second_merged = df_second_merged.fillna(45)

# %%
df_second_merged.head(91)
# Out:
#                  neighborhood  alarms  crimes_rank     0
# 0                   Ridgemont     1.0         45.0  45.0
# 1        Mount Oliver Borough     2.5         45.0  45.0
# 2               New Homestead     2.5         45.0  45.0
# 3                   St. Clair     4.5         52.0  45.0
# 4               Regent Square     4.5         43.0  45.0
# ..                        ...     ...          ...   ...
# 86                  Shadyside    87.0         58.0  37.0
# 87        Squirrel Hill South    88.0         45.0  30.5
# 88           South Side Flats    89.0         45.0   2.0
# 89  Central Business District    90.0         45.0   5.5
# 90                    Carrick    91.0         16.5   9.0
#
# [91 rows x 4 columns]

# %%
df_second_merged.columns = ['neighborhood', 'alarms', 'crimes_rank', 'seized_rank']
df_second_merged.head(10)
# Out:
#            neighborhood  alarms  crimes_rank  seized_rank
# 0             Ridgemont     1.0         45.0         45.0
# 1  Mount Oliver Borough     2.5         45.0         45.0
# 2         New Homestead     2.5         45.0         45.0
# 3             St. Clair     4.5         52.0         45.0
# 4         Regent Square     4.5         43.0         45.0
# 5                  Hays     6.5         45.0         45.0
# 6               Bon Air     6.5         24.0         45.0
# 7        Chartiers City     9.0         45.0         45.0
# 8           South Shore     9.0         45.0         59.0
# 9            Mt. Oliver     9.0         45.0         45.0

# %%
df_second_merged['sum'] = df_second_merged['alarms'] + df_second_merged['crimes_rank'] + df_second_merged['seized_rank']
df_second_merged.head(10)
# Out:
#            neighborhood  alarms  crimes_rank  seized_rank    sum
# 0             Ridgemont     1.0         45.0         45.0   91.0
# 1  Mount Oliver Borough     2.5         45.0         45.0   92.5
# 2         New Homestead     2.5         45.0         45.0   92.5
# 3             St. Clair     4.5         52.0         45.0  101.5
# 4         Regent Square     4.5         43.0         45.0   92.5
# 5                  Hays     6.5         45.0         45.0   96.5
# 6               Bon Air     6.5         24.0         45.0   75.5
# 7        Chartiers City     9.0         45.0         45.0   99.0
# 8           South Shore     9.0         45.0         59.0  113.0
# 9            Mt. Oliver     9.0         45.0         45.0   99.0

# %%
df_second_merged.sort_values(by = 'sum')
# Out:
#            neighborhood  alarms  crimes_rank  seized_rank    sum
# 11       Swisshelm Park    11.5          6.0         45.0   62.5
# 13        East Carnegie    13.5         10.5         45.0   69.0
# 15          Morningside    17.0          3.0         50.0   70.0
# 6               Bon Air     6.5         24.0         45.0   75.5
# 43    Bedford Dwellings    43.5         22.0         23.5   89.0
# ..                  ...     ...          ...          ...    ...
# 73  Squirrel Hill North    74.5         45.0         45.0  164.5
# 60      Central Oakland    61.0         45.0         59.0  165.0
# 71        North Oakland    72.0         60.0         45.0  177.0
# 85         East Liberty    86.0         68.0         25.5  179.5
# 86            Shadyside    87.0         58.0         37.0  182.0
#
# [91 rows x 5 columns]

# %% [markdown]
# ## The Winner Is...........

# %% [markdown]
# ![image.png](https://media.giphy.com/media/11sBLVxNs7v6WA/giphy.gif)

# %% [markdown]
# ### Swisshelm Park!

# %% [markdown]
# **Conclusions:**
#
# **Chris:** I'm not really familiar too much with the neighborhood that was the safest (Swisshelm park), but the conclusion makes sense. It wasn’t necessarily the lowest in any of the two categories it popped up in (crime rate and fires), but it was consistently ranked low in both. Because it didn’t have a rank for gun seizure, it got a 45, but regardless it took the crown. I guess we can conclude that it is a good idea to live in Swisshelm Park when you move to Pittsburgh!
#
#
# **Danny:** Though our three metrics connect to the overall theme of safety, they are all independent. As a result, most of the safer neighborhoods weren’t ranked at the top in all three, but two good rankings were enough to be ranked pretty high. Additionally, it seems as though the crime metric carried the most weight as the safest three neighborhoods were all top 11 (lowest) in crime rate. As a freshman, I am very unfamiliar with most of the Pittsburgh neighborhoods, so it is difficult to tell whether our rankings match up with the consensus. However, it did surprise me how low Oakland was ranked in all three metrics.
#
# **Leon:** I’m only a little familiar with the neighborhoods around the city, but not with the vast majority of them. Swisshelm Park makes sense statistically given it scored very high (lesser value in ranking) in both crime rate and fire, and got the average score of 45 with the firearm seizure rank. East Carnegie is a nicer area that I know of, so that one placing second makes sense. North and Central Oakland placing as low as they did surprised me, but looking at the ranking stats, they were consistently ranked within the bottom third.
